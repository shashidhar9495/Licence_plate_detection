# %%
import pandas as pd
import numpy as np
import CNN_Model,Image_Segmentation
import cv2
import matplotlib.pyplot as plt

# %%
Model=CNN_Model.Model()
Segmentor=Image_Segmentation.Segmentation()

# %%
data=pd.read_csv('dataset.csv',header=None)

# %%
x,y=data.loc[:,0],data.loc[:,1]

# %%
image=cv2.imread(x.iloc[-58])

# %%
prediction=Model.predict_output([x.iloc[-58]],Segmentor)

# %%
prediction
# Out:
# ['3AJ8930']

# %%
plt.imshow(image)
